# %% [markdown]
# # 07 - Reranking y Optimización de Retrieval
#
# ## Curso de LLMs y Aplicaciones de IA
#
# **Duración estimada:** 2 horas
#
# ---
#
# ## Índice
#
# 1. [Introducción al Reranking](#intro)
# 2. [Cross-Encoder](#cross)
# 3. [Bi-Encoder (Dense Retrieval)](#bi)
# 4. [LLM como Reranker](#llm)
# 5. [Estrategias combinadas](#combinadas)
# 6. [Ejercicios prácticos](#ejercicios)
#
# ---
#
# ## Objetivos de aprendizaje
#
# Al finalizar este notebook, serás capaz de:
# - Entender por qué el reranking mejora la calidad del RAG
# - Implementar Cross-Encoder para reranking preciso
# - Comparar Bi-Encoder vs Cross-Encoder
# - Combinar múltiples estrategias de retrieval

# %% [markdown]
# <a name="intro"></a>
# ## 1. Introducción al Reranking
#
# ### ¿Por qué necesitamos Reranking?
#
# La primera fase de retrieval (Bi-Encoder + similitud coseno) es **rápida pero imprecisa**. El reranking añade una segunda fase más precisa pero más costosa.
#
# ```
# Query → [Bi-Encoder] → Top 50 candidatos → [Reranker] → Top 5 finales
#          (rápido)                           (preciso)
# ```
#
# ### Tipos de Rerankers
#
# | Tipo | Descripción | Precisión | Velocidad |
# |------|-------------|-----------|----------|
# | **Cross-Encoder** | Evalúa (query, doc) juntos | Alta | Lenta |
# | **Bi-Encoder** | Embeddings separados | Media | Rápida |
# | **LLM Reranker** | LLM evalúa relevancia | Muy alta | Muy lenta |

# %%
# Install required libraries (all free)
#!pip install -q sentence-transformers torch
# Out:
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import warnings
warnings.filterwarnings('ignore')

# Sample documents for testing
query = "¿Cuáles son las aplicaciones más prometedoras de la IA en medicina?"

documents = [
    "La IA puede acelerar el descubrimiento de nuevos medicamentos para diversos tipos de cáncer.",
    "En cardiología, los modelos predictivos ayudan a identificar pacientes con alto riesgo de infarto.",
    "Los sistemas de IA permiten analizar imágenes médicas para detectar tumores en etapas tempranas.",
    "La IA ha demostrado ser útil en el monitoreo de enfermedades crónicas como la diabetes.",
    "La IA se utiliza para personalizar tratamientos oncológicos según el perfil genético.",
    "En neurología, se emplea IA para detectar patrones de deterioro cognitivo.",
    "Algoritmos se han integrado en hospitales para optimizar la gestión de camas.",
    "La IA permite predecir respuestas a inmunoterapia en pacientes con melanoma.",
    "Me gusta el helado de chocolate.",  # Irrelevant
    "El tiempo está muy agradable hoy.",  # Irrelevant
]

print(f"Query: {query}")
print(f"Documentos: {len(documents)}")
# Out:
# Query: ¿Cuáles son las aplicaciones más prometedoras de la IA en medicina?
# Documentos: 10

# %% [markdown]
# <a name="cross"></a>
# ## 2. Cross-Encoder
#
# El **Cross-Encoder** procesa query y documento **juntos** a través del modelo, permitiendo atención cruzada entre ellos.

# %%
from sentence_transformers import CrossEncoder

# Load Cross-Encoder model (free, open source)
print("Cargando Cross-Encoder...")
cross_encoder = CrossEncoder("cross-encoder/ms-marco-MiniLM-L-6-v2")
print("Modelo cargado ✓")
# Out:
# Cargando Cross-Encoder...
# Loading weights: 100%|██████████| 105/105 [00:00<00:00, 6088.45it/s]
# BertForSequenceClassification LOAD REPORT from: cross-encoder/ms-marco-MiniLM-L-6-v2
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Modelo cargado ✓

# %%
# Create (query, document) pairs
pairs = [(query, doc) for doc in documents]
pairs
# Out:
# [('¿Cuáles son las aplicaciones más prometedoras de la IA en medicina?',
#   'La IA puede acelerar el descubrimiento de nuevos medicamentos para diversos tipos de cáncer.'),
#  ('¿Cuáles son las aplicaciones más prometedoras de la IA en medicina?',
#   'En cardiología, los modelos predictivos ayudan a identificar pacientes con alto riesgo de infarto.'),
#  ('¿Cuáles son las aplicaciones más prometedoras de la IA en medicina?',
#   'Los sistemas de IA permiten analizar imágenes médicas para detectar tumores en etapas tempranas.'),
#  ('¿Cuáles son las aplicaciones más prometedoras de la IA en medicina?',
#   'La IA ha demostrado ser útil en el monitoreo de enfermedades crónicas como la diabetes.'),
#  ('¿Cuáles son las aplicaciones más prometedoras de la IA en medicina?',
#   'La IA se utiliza para personalizar tratamientos oncológicos según el perfil genético.'),
#  ('¿Cuáles son las aplicaciones más prometedoras de la IA en medicina?',
#   'En neurología, se emplea IA para detectar patrones de deterioro cognitivo.'),
#  ('¿Cuáles son las aplicaciones más prometedoras de la IA en medicina?',
#   'Algoritmos se han integrado en hospitales para optimizar la gestión de camas.'),
#  ('¿Cuáles son las aplicaciones más prometedoras de la IA en medicina?',
#   'La IA permite predecir respuestas a inmunoterapia en pacientes con melanoma.'),
#  ('¿Cuáles son las aplicaciones más prometedoras de la IA en medicina?',
#   'Me gusta el helado de chocolate.'),
#  ('¿Cuáles son las aplicaciones más prometedoras de la IA en medicina?',
#   'El tiempo está muy agradable hoy.')]

# %%
# Get relevance scores
scores = cross_encoder.predict(pairs)
scores
# Out:
# array([-10.185188 , -10.931487 , -10.700603 , -10.043789 ,  -9.981315 ,
#        -10.890839 , -10.819911 , -10.1135435, -10.982999 , -10.311857 ],
#       dtype=float32)

# %%
# Sort by score
results = sorted(zip(documents, scores), key=lambda x: x[1], reverse=True)
results
# Out:
# [('La IA se utiliza para personalizar tratamientos oncológicos según el perfil genético.',
#   np.float32(-9.981315)),
#  ('La IA ha demostrado ser útil en el monitoreo de enfermedades crónicas como la diabetes.',
#   np.float32(-10.043789)),
#  ('La IA permite predecir respuestas a inmunoterapia en pacientes con melanoma.',
#   np.float32(-10.1135435)),
#  ('La IA puede acelerar el descubrimiento de nuevos medicamentos para diversos tipos de cáncer.',
#   np.float32(-10.185188)),
#  ('El tiempo está muy agradable hoy.', np.float32(-10.311857)),
#  ('Los sistemas de IA permiten analizar imágenes médicas para detectar tumores en etapas tempranas.',
#   np.float32(-10.700603)),
#  ('Algoritmos se han integrado en hospitales para optimizar la gestión de camas.',
#   np.float32(-10.819911)),
#  ('En neurología, se emplea IA para detectar patrones de deterioro cognitivo.',
#   np.float32(-10.890839)),
#  ('En cardiología, los modelos predictivos ayudan a identificar pacientes con alto riesgo de infarto.',
#   np.float32(-10.931487)),
#  ('Me gusta el helado de chocolate.', np.float32(-10.982999))]

# %%
print("\n🔴 Reranking con Cross-Encoder:")
print("=" * 60)
for i, (doc, score) in enumerate(results, 1):
    emoji = "✅" if score > 0 else "❌"
    print(f"{i}. {emoji} Score: {score:.4f}")
    print(f"   {doc[:70]}...\n")
# Out:
# 🔴 Reranking con Cross-Encoder:
# ============================================================
# 1. ❌ Score: -9.9813
#    La IA se utiliza para personalizar tratamientos oncológicos según el p...
#
# 2. ❌ Score: -10.0438
#    La IA ha demostrado ser útil en el monitoreo de enfermedades crónicas ...
#
# 3. ❌ Score: -10.1135
#    La IA permite predecir respuestas a inmunoterapia en pacientes con mel...
#
# 4. ❌ Score: -10.1852
#    La IA puede acelerar el descubrimiento de nuevos medicamentos para div...
#
# 5. ❌ Score: -10.3119
#    El tiempo está muy agradable hoy....
#
# 6. ❌ Score: -10.7006
#    Los sistemas de IA permiten analizar imágenes médicas para detectar tu...
#
# 7. ❌ Score: -10.8199
#    Algoritmos se han integrado en hospitales para optimizar la gestión de...
#
# 8. ❌ Score: -10.8908
#    En neurología, se emplea IA para detectar patrones de deterioro cognit...
#
# 9. ❌ Score: -10.9315
#    En cardiología, los modelos predictivos ayudan a identificar pacientes...
#
# 10. ❌ Score: -10.9830
#    Me gusta el helado de chocolate....

# %% [markdown]
# <a name="bi"></a>
# ## 3. Bi-Encoder (Dense Retrieval)
#
# El **Bi-Encoder** genera embeddings **separados** para query y documentos, luego calcula similitud.

# %%
from sentence_transformers import SentenceTransformer, util

# Load Bi-Encoder model
print("Cargando Bi-Encoder...")
bi_encoder = SentenceTransformer("all-MiniLM-L6-v2")
print("Modelo cargado ✓")
# Out:
# Cargando Bi-Encoder...
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2732.34it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Modelo cargado ✓

# %%
# Encode query and documents separately
query_embedding = bi_encoder.encode(query, convert_to_tensor=True)
doc_embeddings = bi_encoder.encode(documents, convert_to_tensor=True)
print(query_embedding)
print(doc_embeddings)
# Out:
# tensor([-1.5540e-02,  4.4022e-02, -6.1934e-02, -2.5527e-02, -9.2683e-02,
#         -1.2543e-02,  6.1340e-02,  5.4330e-02,  5.6422e-02,  1.2284e-02,
#          1.2318e-02,  7.1417e-03, -4.2177e-02,  1.7462e-02, -1.0695e-02,
#          3.2967e-02, -4.0872e-02,  1.7212e-02,  4.9868e-02,  3.3632e-02,
#          2.0380e-02,  3.2074e-02, -2.5439e-02,  1.3610e-01, -1.0149e-01,
#          4.3526e-02,  1.9194e-02, -5.1257e-02, -6.2318e-02, -3.6233e-02,
#          1.7288e-02, -2.3788e-02,  1.4919e-01, -1.9913e-02, -1.0537e-02,
#          1.2378e-02, -3.6450e-03, -1.8286e-02, -2.6993e-02,  6.2752e-02,
#         -8.9966e-02, -5.5152e-02, -2.9018e-02,  4.3075e-03,  4.3621e-03,
#         -1.3593e-01, -2.9132e-03,  9.3172e-03, -4.8423e-03,  3.8478e-02,
#         -7.9331e-02, -7.0598e-02, -1.8424e-02,  5.1150e-02,  2.5093e-02,
#         -2.5138e-02, -7.0311e-03, -7.4213e-03, -5.0129e-02,  3.6916e-02,
#          7.3501e-03,  3.7863e-02, -6.9712e-02,  5.0810e-02, -1.8512e-02,
#         -9.5422e-03,  1.2341e-02, -3.4395e-02, -1.5912e-02, -1.7495e-02,
#          7.9284e-02, -1.0097e-01,  1.2480e-02,  3.1860e-02, -4.3660e-03,
#          4.5778e-02, -1.3441e-02, -3.8148e-02, -7.9016e-02, -3.7010e-02,
#          5.4111e-02, -2.5578e-02, -3.5223e-02,  1.2358e-02, -1.5355e-02,
#          4.2639e-02, -4.1694e-02,  5.0421e-02,  1.8503e-03, -8.4613e-03,
#          4.2022e-02, -3.2493e-03, -1.0129e-01, -4.3323e-02, -2.4065e-02,
#          1.7180e-02,  3.0901e-02, -1.1369e-01,  3.3921e-02,  1.6654e-02,
#          5.7257e-02, -1.7819e-02, -1.9022e-02,  4.8044e-02, -7.0524e-02,
#          4.2786e-02,  1.7726e-02, -4.9160e-02,  7.8809e-02,  1.0995e-01,
#         -5.9987e-02, -8.7268e-02, -3.0435e-02,  2.1391e-02, -6.7113e-02,
#          2.9631e-02,  3.1394e-02,  3.8464e-02, -3.4997e-03, -5.7369e-02,
#         -1.8621e-02,  2.7671e-02, -2.3496e-02, -1.0739e-01,  8.1298e-03,
#         -2.7852e-03, -1.1874e-02, -1.0571e-33, -4.2724e-02, -1.0195e-02,
#         -1.4404e-02,  1.2043e-01, -1.6444e-02,  1.1858e-02, -6.0974e-03,
#         -3.1177e-02,  3.8084e-02, -8.2773e-02, -8.1475e-02,  6.9051e-02,
#          2.3221e-02,  5.9502e-02,  1.8201e-02,  6.1812e-02, -2.4284e-02,
#          6.5742e-02,  2.7811e-02,  5.0181e-02, -3.2657e-02,  1.0449e-02,
#         -4.6253e-02,  3.8400e-02,  7.4953e-03,  7.6858e-02, -1.6628e-03,
#         -1.6313e-02,  3.0872e-02,  2.8349e-02,  3.2654e-02,  2.6266e-02,
#         -1.1678e-02, -6.5166e-02, -2.5292e-02,  9.3109e-02,  4.9583e-02,
#          1.8582e-02,  3.2592e-02, -1.1797e-02,  2.1503e-02, -1.0043e-02,
#          4.7216e-02,  4.1866e-02,  5.9526e-02,  2.9310e-02, -4.3880e-02,
#         -2.4199e-02,  3.8720e-02,  1.0157e-02, -6.8379e-02, -7.4887e-02,
#         -5.8523e-02, -4.9157e-02,  2.5274e-02,  4.0752e-02, -9.7405e-02,
#          6.2145e-02,  5.5890e-03, -1.4770e-02,  7.5783e-02,  1.9391e-02,
#         -6.2471e-02,  1.2387e-02, -1.7852e-02, -1.9708e-02,  1.8166e-02,
#         -1.1856e-02,  1.4417e-01,  5.4169e-02, -1.5596e-01, -4.7658e-02,
#          4.6542e-02,  3.6265e-02, -4.7988e-02, -1.1923e-02, -6.6697e-02,
#         -7.5117e-03,  1.1312e-03,  3.3824e-02, -1.2789e-01, -2.6139e-02,
#          4.0302e-03,  7.5079e-02,  9.5121e-02,  5.1874e-02, -1.2134e-02,
#          4.8164e-02, -2.5402e-02,  5.4123e-02, -7.0126e-02,  1.0073e-01,
#         -4.4830e-03,  5.0575e-02,  1.9323e-02, -3.3435e-33,  4.2993e-02,
#         -2.9504e-02,  1.3957e-02,  2.8363e-02,  4.2235e-02,  4.3626e-02,
#         -4.2392e-03, -1.1410e-02,  1.9281e-02, -3.6306e-02, -2.3184e-02,
#         -5.1006e-02,  4.3163e-02, -2.7586e-02, -3.4463e-02,  3.7145e-02,
#         -2.6023e-02, -4.9066e-02, -8.7967e-02, -2.5051e-02, -5.8591e-02,
#          1.0304e-01, -1.0341e-03, -2.6955e-02,  7.0127e-03, -5.7617e-02,
#          5.5957e-02, -6.8150e-04, -3.4838e-03, -4.8814e-02,  5.1931e-02,
#         -2.4378e-02, -7.7220e-02,  2.6990e-02, -6.8110e-02,  9.8889e-02,
#          5.2637e-02,  2.1566e-02, -4.1168e-02,  3.0929e-02,  1.3392e-02,
#          8.9656e-03, -3.8669e-02, -1.8753e-02, -1.0318e-02,  3.9885e-04,
#         -2.9301e-02, -1.0357e-01, -1.1940e-02, -1.0050e-01,  4.4361e-02,
#         -4.5795e-02, -5.3980e-02, -1.9798e-03,  6.8417e-02, -6.8886e-02,
#          2.9631e-02, -9.3127e-02,  2.6057e-02,  1.4293e-02,  8.3612e-02,
#          5.0617e-02, -3.3728e-02,  1.7356e-02,  2.7140e-02,  2.7788e-02,
#          1.3743e-02, -1.6610e-02, -1.8049e-02,  3.7185e-02,  1.2668e-01,
#         -2.5051e-02, -7.7673e-03,  1.4395e-02, -5.4618e-02, -9.6005e-03,
#         -1.1310e-01, -5.6515e-02, -4.3288e-02, -8.1147e-02,  1.6873e-02,
#         -1.0413e-01,  2.0318e-02,  8.0450e-03, -3.0050e-02, -3.7281e-02,
#         -4.7987e-03, -1.5357e-02, -6.7947e-02,  4.4935e-02, -3.4025e-02,
#          1.2373e-02, -5.5743e-02, -5.3029e-02, -1.5136e-02, -2.7582e-08,
#         -2.7136e-03,  1.8824e-03, -2.9779e-02, -5.0995e-02, -1.5559e-02,
#         -4.3057e-02, -5.9206e-02,  1.2579e-01,  2.0086e-02,  1.2405e-02,
#         -6.0835e-02, -1.2457e-03, -2.2774e-02,  8.4121e-02,  5.0411e-02,
#          2.4402e-02,  7.2731e-02,  9.1613e-02, -1.9756e-02, -7.7558e-02,
#          1.9962e-02,  1.4665e-02, -7.5676e-02, -8.1790e-02,  1.0078e-02,
#          4.6980e-02,  2.0499e-03,  5.5399e-02, -1.9273e-02,  2.3289e-02,
#         -4.4637e-02, -7.5771e-04,  2.2298e-02, -5.2849e-02, -3.6288e-03,
#         -2.7175e-02,  4.9022e-02, -3.2416e-02,  5.4869e-03,  6.6073e-03,
#          6.5489e-02, -2.5357e-02, -5.6681e-02, -8.2901e-03, -3.8903e-02,
#         -1.0437e-01,  1.2400e-02,  1.0568e-01, -2.5039e-02,  3.6766e-02,
#          5.0703e-03, -1.9887e-02,  6.1270e-02, -1.1835e-02,  2.7389e-02,
#         -3.0421e-02,  7.5011e-02, -6.3771e-02, -9.1235e-02,  4.1358e-03,
#          1.5117e-01,  1.2166e-02,  1.3712e-01, -1.3392e-01])
# tensor([[ 0.0234, -0.0218, -0.0731,  ..., -0.0197,  0.0808,  0.0184],
#         [-0.0216, -0.0419, -0.0836,  ...,  0.0888,  0.0464, -0.0568],
#         [ 0.0367,  0.0418, -0.0310,  ...,  0.0347,  0.0331, -0.0263],
#         ...,
#         [ 0.0030,  0.0848,  0.0494,  ...,  0.0583,  0.0446, -0.0432],
#         [ 0.0195, -0.0015, -0.0079,  ...,  0.0669, -0.0152, -0.0559],
#         [-0.0289,  0.0572, -0.0023,  ...,  0.1152,  0.0179, -0.0304]])

# %%
# Calculate similarities
similarities = util.cos_sim(query_embedding, doc_embeddings)[0]
similarities
# Out:
# tensor([0.4938, 0.2693, 0.3301, 0.4393, 0.4947, 0.3823, 0.5146, 0.3372, 0.3870,
#         0.4010])

# %%
# Calculate similarities
similarities = util.cos_sim(query_embedding, doc_embeddings)[0]
# Sort by similarity
results_bi = sorted(zip(documents, similarities.tolist()), 
                    key=lambda x: x[1], reverse=True)
results_bi
# Out:
# [('Algoritmos se han integrado en hospitales para optimizar la gestión de camas.',
#   0.5145598649978638),
#  ('La IA se utiliza para personalizar tratamientos oncológicos según el perfil genético.',
#   0.49471360445022583),
#  ('La IA puede acelerar el descubrimiento de nuevos medicamentos para diversos tipos de cáncer.',
#   0.49380481243133545),
#  ('La IA ha demostrado ser útil en el monitoreo de enfermedades crónicas como la diabetes.',
#   0.43933236598968506),
#  ('El tiempo está muy agradable hoy.', 0.40102648735046387),
#  ('Me gusta el helado de chocolate.', 0.3869607150554657),
#  ('En neurología, se emplea IA para detectar patrones de deterioro cognitivo.',
#   0.38226333260536194),
#  ('La IA permite predecir respuestas a inmunoterapia en pacientes con melanoma.',
#   0.3372422456741333),
#  ('Los sistemas de IA permiten analizar imágenes médicas para detectar tumores en etapas tempranas.',
#   0.3300509750843048),
#  ('En cardiología, los modelos predictivos ayudan a identificar pacientes con alto riesgo de infarto.',
#   0.2693081796169281)]

# %%
print("\n🔵 Ranking con Bi-Encoder:")
print("=" * 60)
for i, (doc, score) in enumerate(results_bi, 1):
    emoji = "✅" if score > 0.3 else "❌"
    print(f"{i}. {emoji} Score: {score:.4f}")
    print(f"   {doc[:70]}...\n")
# Out:
# 🔵 Ranking con Bi-Encoder:
# ============================================================
# 1. ✅ Score: 0.5146
#    Algoritmos se han integrado en hospitales para optimizar la gestión de...
#
# 2. ✅ Score: 0.4947
#    La IA se utiliza para personalizar tratamientos oncológicos según el p...
#
# 3. ✅ Score: 0.4938
#    La IA puede acelerar el descubrimiento de nuevos medicamentos para div...
#
# 4. ✅ Score: 0.4393
#    La IA ha demostrado ser útil en el monitoreo de enfermedades crónicas ...
#
# 5. ✅ Score: 0.4010
#    El tiempo está muy agradable hoy....
#
# 6. ✅ Score: 0.3870
#    Me gusta el helado de chocolate....
#
# 7. ✅ Score: 0.3823
#    En neurología, se emplea IA para detectar patrones de deterioro cognit...
#
# 8. ✅ Score: 0.3372
#    La IA permite predecir respuestas a inmunoterapia en pacientes con mel...
#
# 9. ✅ Score: 0.3301
#    Los sistemas de IA permiten analizar imágenes médicas para detectar tu...
#
# 10. ❌ Score: 0.2693
#    En cardiología, los modelos predictivos ayudan a identificar pacientes...

# %% [markdown]
# ### Comparación: Cross-Encoder vs Bi-Encoder

# %%
import time

# Benchmark speed
n_docs = 100
test_docs = documents * 10  # Create 100 documents

# Bi-Encoder timing
start = time.time()
q_emb = bi_encoder.encode(query, convert_to_tensor=True)
d_embs = bi_encoder.encode(test_docs, convert_to_tensor=True)
sims = util.cos_sim(q_emb, d_embs)
bi_time = time.time() - start

# Cross-Encoder timing
start = time.time()
pairs = [(query, doc) for doc in test_docs]
scores = cross_encoder.predict(pairs)
cross_time = time.time() - start

print("Comparación de velocidad:")
print(f"  Bi-Encoder:    {bi_time:.3f}s para {n_docs} docs")
print(f"  Cross-Encoder: {cross_time:.3f}s para {n_docs} docs")
print(f"  Cross-Encoder es {cross_time/bi_time:.1f}x más lento")
# Out:
# Comparación de velocidad:
#   Bi-Encoder:    0.517s para 100 docs
#   Cross-Encoder: 1.151s para 100 docs
#   Cross-Encoder es 2.2x más lento

# %% [markdown]
# <a name="llm"></a>
# ## 4. LLM como Reranker
#
# Un LLM puede evaluar la relevancia de documentos con alta precisión, pero es el método más costoso.

# %%
import os
from getpass import getpass

if 'GROQ_API_KEY' not in os.environ:
    os.environ['GROQ_API_KEY'] = getpass("Introduce tu GROQ API Key: ")

from langchain_groq import ChatGroq

llm = ChatGroq(model_name="llama-3.3-70b-versatile", temperature=0)
print("LLM configurado ✓")
# Out:
# LLM configurado ✓

# %%
def llm_rerank(query: str, documents: list, top_k: int = 5) -> list:
    """Use LLM to rerank documents by relevance."""
    
    # Format documents with indices
    doc_list = "\n".join([f"[{i+1}] {doc}" for i, doc in enumerate(documents)])
    
    prompt = f"""Ordena los siguientes documentos por relevancia para la pregunta.
Devuelve SOLO los números de los {top_k} documentos más relevantes, separados por comas.

Pregunta: {query}

Documentos:
{doc_list}

Top {top_k} más relevantes (solo números, ej: 3,1,5,2,4):"""
    
    response = llm.invoke(prompt)
    
    # Parse response
    try:
        indices = [int(x.strip()) - 1 for x in response.content.split(",")[:top_k]]
        return [(documents[i], i+1) for i in indices if 0 <= i < len(documents)]
    except:
        return [(doc, i) for i, doc in enumerate(documents[:top_k], 1)]

# Test LLM reranking
print("🟣 Reranking con LLM:")
print("=" * 60)

llm_results = llm_rerank(query, documents, top_k=5)
for i, (doc, original_idx) in enumerate(llm_results, 1):
    print(f"{i}. (original #{original_idx}) {doc[:60]}...")
# Out:
# 🟣 Reranking con LLM:
# ============================================================
# 1. (original #1) La IA puede acelerar el descubrimiento de nuevos medicamento...
# 2. (original #3) Los sistemas de IA permiten analizar imágenes médicas para d...
# 3. (original #5) La IA se utiliza para personalizar tratamientos oncológicos ...
# 4. (original #2) En cardiología, los modelos predictivos ayudan a identificar...
# 5. (original #4) La IA ha demostrado ser útil en el monitoreo de enfermedades...

# %% [markdown]
# <a name="combinadas"></a>
# ## 5. Estrategias Combinadas
#
# La mejor práctica es combinar Bi-Encoder (rápido, primera fase) con Cross-Encoder (preciso, segunda fase).

# %%
def two_stage_retrieval(query: str, documents: list, 
                        bi_model, cross_model,
                        first_k: int = 10, final_k: int = 5):
    """
    Two-stage retrieval:
    1. Bi-Encoder for fast initial retrieval
    2. Cross-Encoder for precise reranking
    """
    # Stage 1: Bi-Encoder
    q_emb = bi_model.encode(query, convert_to_tensor=True)
    d_embs = bi_model.encode(documents, convert_to_tensor=True)
    sims = util.cos_sim(q_emb, d_embs)[0]
    
    # Get top-k candidates
    top_indices = sims.argsort(descending=True)[:first_k]
    candidates = [(documents[i], sims[i].item()) for i in top_indices]
    
    print(f"Stage 1 (Bi-Encoder): {len(candidates)} candidatos")
    
    # Stage 2: Cross-Encoder
    pairs = [(query, doc) for doc, _ in candidates]
    scores = cross_model.predict(pairs)
    
    # Final ranking
    final_results = sorted(zip([c[0] for c in candidates], scores), 
                          key=lambda x: x[1], reverse=True)[:final_k]
    
    print(f"Stage 2 (Cross-Encoder): {len(final_results)} resultados finales")
    
    return final_results

# Test two-stage retrieval
print("\n🔶 Two-Stage Retrieval:")
print("=" * 60)

final_results = two_stage_retrieval(
    query, documents,
    bi_encoder, cross_encoder,
    first_k=8, final_k=5
)

print("\nResultados finales:")
for i, (doc, score) in enumerate(final_results, 1):
    print(f"{i}. Score: {score:.4f}")
    print(f"   {doc[:70]}...\n")
# Out:
# 🔶 Two-Stage Retrieval:
# ============================================================
# Stage 1 (Bi-Encoder): 8 candidatos
# Stage 2 (Cross-Encoder): 5 resultados finales
#
# Resultados finales:
# 1. Score: -9.9813
#    La IA se utiliza para personalizar tratamientos oncológicos según el p...
#
# 2. Score: -10.0438
#    La IA ha demostrado ser útil en el monitoreo de enfermedades crónicas ...
#
# 3. Score: -10.1135
#    La IA permite predecir respuestas a inmunoterapia en pacientes con mel...
#
# 4. Score: -10.1852
#    La IA puede acelerar el descubrimiento de nuevos medicamentos para div...
#
# 5. Score: -10.3119
#    El tiempo está muy agradable hoy....

# %% [markdown]
# <a name="ejercicios"></a>
# ## 6. Ejercicios Prácticos
#
# ### Ejercicio 1: Comparar rankings

# %%
# Exercise 1: Compare all three methods on a new query

new_query = "¿Cómo ayuda la inteligencia artificial a diagnosticar enfermedades?"

# Get rankings from all three methods
# 1. Bi-Encoder
# 2. Cross-Encoder  
# 3. LLM

# Compare which documents appear in top 3 for each
# Are they the same? Different?

print(f"Query: {new_query}")
print("\nCompara los rankings de cada método...")
# Out:
# Query: ¿Cómo ayuda la inteligencia artificial a diagnosticar enfermedades?
#
# Compara los rankings de cada método...

# %% [markdown]
# 1. Bi-Encoder

# %%
query_embedding = bi_encoder.encode(new_query, convert_to_tensor=True)
doc_embeddings = bi_encoder.encode(documents, convert_to_tensor=True)

# Calculate similarities
similarities = util.cos_sim(query_embedding, doc_embeddings)[0]

# Sort by similarity
results_bi = sorted(zip(documents, similarities.tolist()), 
                    key=lambda x: x[1], reverse=True)

print(f"Query: {new_query}")
print("\n🔵 Ranking con Bi-Encoder:")
print("=" * 60)
for i, (doc, score) in enumerate(results_bi, 1):
    emoji = "✅" if score > 0.3 else "❌"
    print(f"{i}. {emoji} Score: {score:.4f}")
    print(f"   {doc[:70]}...\n")
# Out:
# Query: ¿Cómo ayuda la inteligencia artificial a diagnosticar enfermedades?
#
# 🔵 Ranking con Bi-Encoder:
# ============================================================
# 1. ✅ Score: 0.4737
#    En neurología, se emplea IA para detectar patrones de deterioro cognit...
#
# 2. ✅ Score: 0.4722
#    La IA ha demostrado ser útil en el monitoreo de enfermedades crónicas ...
#
# 3. ✅ Score: 0.4720
#    Algoritmos se han integrado en hospitales para optimizar la gestión de...
#
# 4. ✅ Score: 0.4203
#    Los sistemas de IA permiten analizar imágenes médicas para detectar tu...
#
# 5. ✅ Score: 0.3533
#    La IA se utiliza para personalizar tratamientos oncológicos según el p...
#
# 6. ✅ Score: 0.3217
#    La IA puede acelerar el descubrimiento de nuevos medicamentos para div...
#
# 7. ✅ Score: 0.3187
#    En cardiología, los modelos predictivos ayudan a identificar pacientes...
#
# 8. ✅ Score: 0.3086
#    El tiempo está muy agradable hoy....
#
# 9. ❌ Score: 0.2745
#    La IA permite predecir respuestas a inmunoterapia en pacientes con mel...
#
# 10. ❌ Score: 0.2417
#    Me gusta el helado de chocolate....

# %% [markdown]
# 2. Cross-Encoder

# %%
# Create (query, document) pairs
pairs = [(new_query, doc) for doc in documents]

# Get relevance scores
scores = cross_encoder.predict(pairs)

# Sort by score
results = sorted(zip(documents, scores), key=lambda x: x[1], reverse=True)

print("\n🔴 Reranking con Cross-Encoder:")
print("=" * 60)
for i, (doc, score) in enumerate(results, 1):
    emoji = "✅" if score > 0 else "❌"
    print(f"{i}. {emoji} Score: {score:.4f}")
    print(f"   {doc[:70]}...\n")
# Out:
# 🔴 Reranking con Cross-Encoder:
# ============================================================
# 1. ❌ Score: -5.2696
#    La IA ha demostrado ser útil en el monitoreo de enfermedades crónicas ...
#
# 2. ❌ Score: -9.0910
#    En cardiología, los modelos predictivos ayudan a identificar pacientes...
#
# 3. ❌ Score: -10.7143
#    Los sistemas de IA permiten analizar imágenes médicas para detectar tu...
#
# 4. ❌ Score: -10.7698
#    En neurología, se emplea IA para detectar patrones de deterioro cognit...
#
# 5. ❌ Score: -11.1171
#    El tiempo está muy agradable hoy....
#
# 6. ❌ Score: -11.1649
#    La IA puede acelerar el descubrimiento de nuevos medicamentos para div...
#
# 7. ❌ Score: -11.1684
#    Algoritmos se han integrado en hospitales para optimizar la gestión de...
#
# 8. ❌ Score: -11.2018
#    La IA permite predecir respuestas a inmunoterapia en pacientes con mel...
#
# 9. ❌ Score: -11.2493
#    La IA se utiliza para personalizar tratamientos oncológicos según el p...
#
# 10. ❌ Score: -11.4089
#    Me gusta el helado de chocolate....

# %%
# Benchmark speed
n_docs = 100
test_docs = documents * 10  # Create 100 documents

# Bi-Encoder timing
start = time.time()
q_emb = bi_encoder.encode(new_query, convert_to_tensor=True)
d_embs = bi_encoder.encode(test_docs, convert_to_tensor=True)
sims = util.cos_sim(q_emb, d_embs)
bi_time = time.time() - start

# Cross-Encoder timing
start = time.time()
pairs = [(new_query, doc) for doc in test_docs]
scores = cross_encoder.predict(pairs)
cross_time = time.time() - start

print("Comparación de velocidad:")
print(f"  Bi-Encoder:    {bi_time:.3f}s para {n_docs} docs")
print(f"  Cross-Encoder: {cross_time:.3f}s para {n_docs} docs")
print(f"  Cross-Encoder es {cross_time/bi_time:.1f}x más lento")
# Out:
# Comparación de velocidad:
#   Bi-Encoder:    1.477s para 100 docs
#   Cross-Encoder: 2.420s para 100 docs
#   Cross-Encoder es 1.6x más lento

# %% [markdown]
# ## Resumen
#
# En este notebook hemos aprendido:
#
# 1. **Reranking**: Segunda fase para mejorar precisión
# 2. **Cross-Encoder**: Preciso pero lento
# 3. **Bi-Encoder**: Rápido pero menos preciso
# 4. **LLM Reranker**: Muy preciso pero costoso
# 5. **Two-stage**: Combinar lo mejor de ambos
#
# ### Recomendaciones
#
# | Escenario | Estrategia recomendada |
# |-----------|------------------------|
# | Latencia crítica | Solo Bi-Encoder |
# | Precisión crítica | Two-stage (Bi + Cross) |
# | Pocos documentos | Cross-Encoder directo |
# | Máxima precisión | LLM Reranker |
#
# En el siguiente notebook veremos **Agentes**, que combinan LLMs con herramientas y razonamiento.
#
# ---
#
# ## Referencias
#
# - [Sentence Transformers](https://www.sbert.net/)
# - [Cross-Encoders for Reranking](https://www.sbert.net/examples/applications/cross-encoder/README.html)

# %%
import session_info
session_info.show(html = False)
# Out:
# -----
# ipykernel                   7.2.0
# langchain_groq              1.1.2
# sentence_transformers       5.2.2
# session_info                v1.0.1
# torch                       2.10.0+cpu
# -----
# IPython             9.10.0
# jupyter_client      8.8.0
# jupyter_core        5.9.1
# -----
# Python 3.13.1 (tags/v3.13.1:0671451, Dec  3 2024, 19:06:28) [MSC v.1942 64 bit (AMD64)]
# Windows-11-10.0.26200-SP0
# -----
# Session information updated at 2026-02-09 17:25
