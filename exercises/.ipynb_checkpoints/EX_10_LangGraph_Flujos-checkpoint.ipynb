# %% [markdown]
# # EX_10 — LangGraph y flujos (ejercicios)
#
# **Notebook de referencia:** `notebook/10_LangGraph_Flujos.ipynb`
#
# **Tiempo orientativo:** ~30 minutos.

# %% [markdown]
# ## Actividad 1 — Estado TypedDict
#
# Define un `TypedDict` de estado con al menos: `question: str`, `answer: str`, `step_count: int`.

# %%
from typing import TypedDict

class QAState(TypedDict):
    question: str
    answer: str
    step_count: int

# %% [markdown]
# ## Actividad 2 — Dos nodos
#
# Esquematiza (pseudocódigo) nodos `retrieve` y `generate` que incrementen `step_count`. No hace falta ejecutar LangGraph si aún no está importado en el entorno.

# %%
def retrieve(state: QAState) -> dict:
    current_steps = state.get("step_count", 0) + 1
    print(f"[Nodo retrieve] Incrementando step_count a: {current_steps}")
    return {"step_count": current_steps}

def generate(state: QAState) -> dict:
    current_steps = state.get("step_count", 0) + 1
    print(f"[Nodo generate] Incrementando step_count a: {current_steps}")
    return {
        "step_count": current_steps, 
        "answer": "Respuesta generada en base al contexto obtenido."
    }

# %% [markdown]
# ## Actividad 3 — Condicional
#
# Describe en markdown cuándo enrutarías a un nodo `human_review` (p. ej. si `confidence < 0.5`).

# %% [markdown]
# __Criterio de enrutamiento:_
#
# Enrutaría el flujo hacia un nodo llamado `human_review` bajo las siguientes condiciones:
#
# 1. **Umbral de Confianza Bajo (`confidence < 0.5`)**: Si el modelo de clasificación o de extracción devuelve una puntuación de seguridad inferior a un umbral predefinido (ej. 50%), indicando que la duda es muy ambigua.
# 2. **Fallo repetido en validaciones automáticas**: Si el contador del estado (`step_count`) supera un límite (ej. ha pasado 3 veces por el nodo de auto-corrección) y sigue sin superar el control de calidad automático.
# 3. **Detección de temas sensibles o críticos**: Si el nodo de clasificación identifica que la pregunta del usuario toca temas legales, financieros críticos, médicos o de soporte de nivel avanzado que por política interna exijan supervisión humana directa.
#
# **Implementación en LangGraph**:
# Se crearía una función de enrutamiento condicional (`router_function`) que evalúe dichos parámetros del estado y devuelva `"human_review"` si se cumple alguna regla, o `END` (o el siguiente nodo estándar) si todo es correcto.
