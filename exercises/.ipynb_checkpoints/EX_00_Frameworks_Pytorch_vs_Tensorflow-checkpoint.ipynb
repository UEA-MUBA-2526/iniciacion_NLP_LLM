# %% [markdown]
# # EX_00 — PyTorch vs TensorFlow (ejercicios)
#
# **Notebook de referencia:** `notebook/00_Frameworks_Pytorch_vs_Tensorflow.ipynb`
#
# **Tiempo orientativo:** ~30 minutos.
#
# En esta hoja practicarás ideas equivalentes en ambos frameworks: tensores, capas lineales y un forward pass mínimo.

# %% [markdown]
# ## Actividad 1 — Activación a mano
#
# Implementa en NumPy una función `relu` y otra `sigmoid` y comprueba que coinciden con `torch` y `tensorflow` en un vector de prueba.
#
# *Hint:* use `torch.relu`, `tf.nn.relu`; for sigmoid use `torch.sigmoid` and `tf.nn.sigmoid`.

# %%
import numpy as np
import torch
import tensorflow as tf

# 1. Implementación a mano de las funciones de activación solicitadas en NumPy
def relu_np(z):
    return np.maximum(0, z)

def sigmoid_np(z):
    # Sigmoid: 1 / (1 + e^-z)
    return 1 / (1 + np.exp(-z))

x = np.array([-2.0, 0.0, 1.5], dtype=np.float32)

#Cálculo de las salidas con funciones NumPy
out_relu_np = relu_np(x)
out_sigmoid_np = sigmoid_np(x)

#Conversión a tensores y cálculo con PyTorch
x_torch = torch.tensor(x)
out_relu_torch = torch.relu(x_torch).numpy()
out_sigmoid_torch = torch.sigmoid(x_torch).numpy()

#Conversión a tensores y cálculo con TensorFlow
x_tf = tf.convert_to_tensor(x)
out_relu_tf = tf.nn.relu(x_tf).numpy()
out_sigmoid_tf = tf.nn.sigmoid(x_tf).numpy()

#Comprobación usando asserts para asegurar que los valores coinciden
np.testing.assert_allclose(out_relu_np, out_relu_torch, rtol=1e-5, atol=1e-5)
np.testing.assert_allclose(out_relu_np, out_relu_tf, rtol=1e-5, atol=1e-5)

np.testing.assert_allclose(out_sigmoid_np, out_sigmoid_torch, rtol=1e-5, atol=1e-5)
np.testing.assert_allclose(out_sigmoid_np, out_sigmoid_tf, rtol=1e-5, atol=1e-5)

print("=== ¡Actividad 1 Completada! ===")
print(f"Salida NumPy ReLU: {out_relu_np} -> Coincide con PyTorch y TF")
print(f"Salida NumPy Sigmoid: {out_sigmoid_np} -> Coincide con PyTorch y TF")
# Out:
# 2026-05-27 18:53:02.560366: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# === ¡Actividad 1 Completada! ===
# Salida NumPy ReLU: [0.  0.  1.5] -> Coincide con PyTorch y TF
# Salida NumPy Sigmoid: [0.11920293 0.5        0.8175745 ] -> Coincide con PyTorch y TF

# %% [markdown]
# ## Actividad 2 — Misma arquitectura, dos APIs
#
# Define una red `Linear(10, 3)` + `ReLU` + `Linear(3, 1)` en **PyTorch** (`nn.Sequential`) y la misma en **Keras** (`Sequential`).
#
# *Hint:* set seeds (`torch.manual_seed`, `tf.random.set_seed`) and use explicit init if you want to compare weights.

# %%
import torch
import torch.nn as nn
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np

# Fijamos semillas globales en ambos frameworks para controlar la aleatoriedad inicial
torch.manual_seed(42)
tf.random.set_seed(42)

#Definición del modelo secuencial en PyTorch
torch_model = nn.Sequential(
    nn.Linear(10, 3),
    nn.ReLU(),
    nn.Linear(3, 1)
)

# Definición del mismo modelo en Keras usando inicializadores explícitos
# Usamos RandomNormal e inicializadores a cero en los sesgos para un control idéntico si fuese necesario
keras_model = keras.Sequential([
    layers.Input(shape=(10,)),  # Definimos la dimensión de entrada explícitamente
    layers.Dense(3, activation='relu', 
                 kernel_initializer=keras.initializers.RandomNormal(seed=42),
                 bias_initializer='zeros'),
    layers.Dense(1, 
                 kernel_initializer=keras.initializers.RandomNormal(seed=42),
                 bias_initializer='zeros')
])

# Muestrear una entrada aleatoria con dimensiones fijas (batch=4, features=10)
x_src = np.random.randn(4, 10).astype(np.float32)

# Conversión a tensores y Forward Pass en PyTorch
x_torch = torch.tensor(x_src)
output_torch = torch_model(x_torch)

# Conversión a tensores y Forward Pass en Keras
x_tf = tf.convert_to_tensor(x_src)
output_keras = keras_model(x_tf)

print("=== ¡Actividad 2 Completada! ===")
print(f"Entrada original - Dimensiones: {x_src.shape}")
print(f"Salida PyTorch   - Dimensiones: {output_torch.shape}")
print(f"Salida Keras     - Dimensiones: {output_keras.shape}")
# Out:
# === ¡Actividad 2 Completada! ===
# Entrada original - Dimensiones: (4, 10)
# Salida PyTorch   - Dimensiones: torch.Size([4, 1])
# Salida Keras     - Dimensiones: (4, 1)

# %% [markdown]
# ## Actividad 3 — Entrenamiento en mini-batch (conceptual + código corto)
#
# Escribe un bucle de **una época** que: (1) muestree un batch sintético `X, y` para regresión, (2) calcule `MSE`, (3) haga `backward` / `gradient` y un paso de optimizador.
#
# Elige **solo uno** de los dos frameworks para el bucle completo; en el otro, documenta en un comentario qué API usarías (`loss.backward`, `tape.gradient`, etc.).

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

# Configuración inicial y generación de datos sintéticos estables
np.random.seed(42)
torch.manual_seed(42)

# Simulamos datos para regresión: 4 mini-batches, cada uno con un tamaño de batch de 8 y 10 características
X_batches = np.random.randn(4, 8, 10).astype(np.float32)
y_batches = np.random.randn(4, 8, 1).astype(np.float32)


# Definimos una red simple (capa lineal de regresión), la función de pérdida MSE y el optimizador SGD
model = nn.Linear(10, 1)
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

print("=== Iniciando 1 Época de Entrenamiento Completa (PyTorch) ===")

# Recorremos cada uno de los mini-batches sintéticos creados
for i in range(len(X_batches)):
    # 1. Muestreo del batch convirtiendo los datos a tensores
    X_batch = torch.tensor(X_batches[i])
    y_batch = torch.tensor(y_batches[i])
    
    # Forward Pass: Calcular predicción y calcular el coste (MSE)
    predictions = model(X_batch)
    loss = criterion(predictions, y_batch)
    
    # 2. Paso backward / cálculo de gradientes y actualización con el optimizador
    optimizer.zero_grad()  # Limpiamos gradientes anteriores acumulados
    loss.backward()        # Backpropagation: cálculo de gradientes internos
    optimizer.step()       # Ajuste de pesos en función del gradiente obtenido
    
    print(f"Mini-batch [{i+1}/4] -> Loss MSE actual: {loss.item():.4f}")
# Out:
# === Iniciando 1 Época de Entrenamiento Completa (PyTorch) ===
# Mini-batch [1/4] -> Loss MSE actual: 2.3798
# Mini-batch [2/4] -> Loss MSE actual: 0.6492
# Mini-batch [3/4] -> Loss MSE actual: 0.5233
# Mini-batch [4/4] -> Loss MSE actual: 0.7994
